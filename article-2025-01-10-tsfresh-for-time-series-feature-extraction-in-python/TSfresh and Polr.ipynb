# %%
import pandas as pd
# Create a time series DataFrame
date_range = pd.date_range(start="2023-01-01", periods=10, freq="D")
data = pd.DataFrame({"value": range(10)}, index=date_range)
# Shift and rolling mean
data["shifted"] = data["value"].shift(1)
data["rolling_mean"] = data["value"].rolling(window=3).mean()
print(data)
import statsmodels.api as sm
# Simulated data
data = sm.datasets.macrodata.load_pandas().data
inflation = data["infl"]
# Fit ARIMA model
model = sm.tsa.ARIMA(inflation, order=(1, 1, 1))
results = model.fit()
print(results.summary())
from tsfresh import extract_features
from tsfresh.utilities.dataframe_functions import make_forecasting_frame
# Create example time series data
df = pd.DataFrame({
    "id": [1]*10 + [2]*10,
    "time": list(range(10)) + list(range(10)),
    "value": range(20)
})


from prophet import Prophet
# Create example time series data
df = pd.DataFrame({
    "ds": pd.date_range(start="2023-01-01", periods=100, freq="D"),
    "y": range(100)
})
# Fit model
model = Prophet()
model.fit(df)
# Make future predictions
future = model.make_future_dataframe(periods=30)
forecast = model.predict(future)
print(forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail())
import torch
import torch.nn as nn
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size)
        self.fc = nn.Linear(hidden_size, output_size)
    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.fc(x[-1])
        return x
# Initialize model
model = LSTMModel(input_size=1, hidden_size=10, output_size=1)
print(model)
import polars as pl
# Create a time series DataFrame
df = pl.DataFrame({
    "timestamp": pl.date_range("2023-01-01", "2023-01-10", "1d"),
    "value": range(10)
})
# Compute rolling mean
df = df.with_columns(df["value"].rolling_mean(window_size=3).alias("rolling_mean"))
print(df)
# Out:
#             value  shifted  rolling_mean
# 2023-01-01      0      NaN           NaN
# 2023-01-02      1      0.0           NaN
# 2023-01-03      2      1.0           1.0
# 2023-01-04      3      2.0           2.0
# 2023-01-05      4      3.0           3.0
# 2023-01-06      5      4.0           4.0
# 2023-01-07      6      5.0           5.0
# 2023-01-08      7      6.0           6.0
# 2023-01-09      8      7.0           7.0
# 2023-01-10      9      8.0           8.0
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   infl   No. Observations:                  203
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -456.713
# Date:                Sat, 15 Feb 2025   AIC                            919.426
# Time:                        20:43:08   BIC                            929.350
# Sample:                             0   HQIC                           923.441
#                                 - 203
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0002      0.067      0.003      0.998      -0.130       0.131
# ma.L1         -0.6279      0.064     -9.831      0.000      -0.753      -0.503
# sigma2         5.3739      0.321     16.753      0.000       4.745       6.003
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               182.21
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.75   Skew:                            -1.02
# Prob(H) (two-sided):                  0.02   Kurtosis:                         7.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 17
#      15 results = model.fit()
#      16 print(results.summary())
# ---> 17 from tsfresh import extract_features
#      18 from tsfresh.utilities.dataframe_functions import make_forecasting_frame
#      19 # Create example time series data
#
# File /opt/anaconda3/lib/python3.12/site-packages/tsfresh/__init__.py:27
#      22 from logging import NullHandler
#      24 logging.getLogger(__name__).addHandler(NullHandler())
# ---> 27 from tsfresh.convenience.relevant_extraction import (  # noqa: E402
#      28     extract_relevant_features,
#      29 )
#      30 from tsfresh.feature_extraction import extract_features  # noqa: E402
#      31 from tsfresh.feature_selection import select_features
#
# File /opt/anaconda3/lib/python3.12/site-packages/tsfresh/convenience/relevant_extraction.py:8
#       5 import pandas as pd
#       7 from tsfresh import defaults
# ----> 8 from tsfresh.feature_extraction import extract_features
#       9 from tsfresh.feature_selection import select_features
#      10 from tsfresh.utilities.dataframe_functions import (
#      11     get_ids,
#      12     impute,
#      13     restrict_input_to_index,
#      14 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/tsfresh/feature_extraction/__init__.py:5
#       1 """
#       2 The :mod:`tsfresh.feature_extraction` module contains methods to extract the features from the time series
#       3 """
# ----> 5 from tsfresh.feature_extraction.extraction import extract_features
#       6 from tsfresh.feature_extraction.settings import (
#       7     ComprehensiveFCParameters,
#       8     EfficientFCParameters,
#       9     MinimalFCParameters,
#      10 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/tsfresh/feature_extraction/extraction.py:15
#      12 import pandas as pd
#      14 from tsfresh import defaults
# ---> 15 from tsfresh.feature_extraction import feature_calculators
#      16 from tsfresh.feature_extraction.data import to_tsdata
#      17 from tsfresh.feature_extraction.settings import ComprehensiveFCParameters
#
# File /opt/anaconda3/lib/python3.12/site-packages/tsfresh/feature_extraction/feature_calculators.py:30
#      28 import stumpy
#      29 from numpy.linalg import LinAlgError
# ---> 30 from scipy.signal import cwt, find_peaks_cwt, ricker, welch
#      31 from scipy.stats import linregress
#      32 from statsmodels.tools.sm_exceptions import MissingDataError
#
# ImportError: cannot import name 'cwt' from 'scipy.signal' (/opt/anaconda3/lib/python3.12/site-packages/scipy/signal/__init__.py)

# %%
# !pip install tsfresh
# Out:
# Collecting tsfresh
#   Downloading tsfresh-0.20.3-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: requests>=2.9.1 in /opt/anaconda3/lib/python3.12/site-packages (from tsfresh) (2.32.3)
# Requirement already satisfied: numpy>=1.15.1 in /opt/anaconda3/lib/python3.12/site-packages (from tsfresh) (1.26.4)
# Requirement already satisfied: pandas>=0.25.0 in /opt/anaconda3/lib/python3.12/site-packages (from tsfresh) (2.2.2)
# Requirement already satisfied: statsmodels>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from tsfresh) (0.14.2)
# Requirement already satisfied: patsy>=0.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from tsfresh) (0.5.6)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from tsfresh) (1.5.1)
# Requirement already satisfied: tqdm>=4.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from tsfresh) (4.66.5)
# Collecting stumpy>=1.7.2 (from tsfresh)
#   Downloading stumpy-1.13.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/lib/python3.12/site-packages (from tsfresh) (3.0.0)
# Collecting scipy>=1.14.0 (from tsfresh)
#   Downloading scipy-1.15.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.25.0->tsfresh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.25.0->tsfresh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.25.0->tsfresh) (2023.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from patsy>=0.4.1->tsfresh) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.9.1->tsfresh) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.9.1->tsfresh) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.9.1->tsfresh) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.9.1->tsfresh) (2024.12.14)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22.0->tsfresh) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22.0->tsfresh) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels>=0.13->tsfresh) (24.1)
# Requirement already satisfied: numba>=0.57.1 in /opt/anaconda3/lib/python3.12/site-packages (from stumpy>=1.7.2->tsfresh) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/lib/python3.12/site-packages (from numba>=0.57.1->stumpy>=1.7.2->tsfresh) (0.43.0)
# Downloading tsfresh-0.20.3-py2.py3-none-any.whl (95 kB)
# Downloading scipy-1.15.1-cp312-cp312-macosx_14_0_arm64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 7.6 MB/s eta 0:00:0000:0100:01
# Downloading stumpy-1.13.0-py3-none-any.whl (176 kB)
# Installing collected packages: scipy, stumpy, tsfresh
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.1 which is incompatible.
# Successfully installed scipy-1.15.1 stumpy-1.13.0 tsfresh-0.20.3

# %%
import pandas as pd
import statsmodels.api as sm

from prophet import Prophet
import torch
import torch.nn as nn
import polars as pl

# Load dataset
file_path = "north_dakota_oil_price.csv"
data = pd.read_csv(file_path, parse_dates=["Date"])
data.set_index("Date", inplace=True)

# Shift and rolling mean
data["shifted"] = data["Oil_Price"].shift(1)
data["rolling_mean"] = data["Oil_Price"].rolling(window=3).mean()
print(data.head())

# ARIMA model
inflation = data["Oil_Price"].dropna()
model = sm.tsa.ARIMA(inflation, order=(1, 1, 1))
results = model.fit()
print(results.summary())



# Prophet model
df_prophet = data.reset_index().rename(columns={"Date": "ds", "Oil_Price": "y"})
model = Prophet()
model.fit(df_prophet)
future = model.make_future_dataframe(periods=30)
forecast = model.predict(future)
print(forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail())

# LSTM Model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.fc(x[-1])
        return x

# Initialize model
model = LSTMModel(input_size=1, hidden_size=10, output_size=1)
print(model)

# Polars rolling mean
df_polars = pl.read_csv(file_path)
df_polars = df_polars.with_columns(
    pl.col("Oil_Price").rolling_mean(window_size=3).alias("rolling_mean")
)
print(df_polars.head())
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency -1MS will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency -1MS will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency -1MS will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/statespace/mlemodel.py:3158: UserWarning: Early subset of data for variable 0 has too few non-missing observations to calculate test statistic.
#   test_statistic, p_value = breakvar_heteroskedasticity_test(
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/statespace/mlemodel.py:3158: UserWarning: Later subset of data for variable 0 has too few non-missing observations to calculate test statistic.
#   test_statistic, p_value = breakvar_heteroskedasticity_test(
# 20:44:23 - cmdstanpy - INFO - Chain [1] start processing
#             Oil_Price  shifted  rolling_mean
# Date
# 2024-11-01      64.49      NaN           NaN
# 2024-10-01      66.98    64.49           NaN
# 2024-09-01      64.52    66.98     65.330000
# 2024-08-01      70.62    64.52     67.373333
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              Oil_Price   No. Observations:                    4
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                  -7.543
# Date:                Sat, 15 Feb 2025   AIC                             21.087
# Time:                        20:44:23   BIC                             18.383
# Sample:                             0   HQIC                            15.651
#                                   - 4
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8905   3.05e+04  -2.92e-05      1.000   -5.97e+04    5.97e+04
# ma.L1          0.2616   9.73e+04   2.69e-06      1.000   -1.91e+05    1.91e+05
# sigma2         6.1662   2.02e+05   3.06e-05      1.000   -3.95e+05    3.95e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.52   Jarque-Bera (JB):                 0.30
# Prob(Q):                              0.22   Prob(JB):                         0.86
# Heteroskedasticity (H):                nan   Skew:                             0.17
# Prob(H) (two-sided):                   nan   Kurtosis:                         1.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 20:44:23 - cmdstanpy - INFO - Chain [1] done processing
#            ds       yhat  yhat_lower  yhat_upper
# 29 2024-11-27  62.884766   60.676577   65.099904
# 30 2024-11-28  62.832445   60.532967   64.912279
# 31 2024-11-29  62.780124   60.423846   64.945439
# 32 2024-11-30  62.727803   60.391829   65.028852
# 33 2024-12-01  62.675482   60.430167   64.954326
# LSTMModel(
#   (lstm): LSTM(1, 10)
#   (fc): Linear(in_features=10, out_features=1, bias=True)
# )
# shape: (4, 3)
# ┌───────────┬────────────┬──────────────┐
# │ Oil_Price ┆ Date       ┆ rolling_mean │
# │ ---       ┆ ---        ┆ ---          │
# │ f64       ┆ str        ┆ f64          │
# ╞═══════════╪════════════╪══════════════╡
# │ 64.49     ┆ 2024-11-01 ┆ null         │
# │ 66.98     ┆ 2024-10-01 ┆ null         │
# │ 64.52     ┆ 2024-09-01 ┆ 65.33        │
# │ 70.62     ┆ 2024-08-01 ┆ 67.373333    │
# └───────────┴────────────┴──────────────┘
